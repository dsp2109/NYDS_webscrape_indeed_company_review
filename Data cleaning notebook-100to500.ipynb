# %% [markdown]
# ## Cleaning the data scraped from indeed.com
#
# #### Steps taken:
# 1. add company-wide columns that pick bar pct for:
#        Quick-paced
#        Slow-paced
#        Stressful
#        Balanced
#        Competitive
#        Relaxed
#        Cut-throat
# 2. add company-wide columns for ratings:
#     Compensation/Benefits
#     Culture
#     Job Security
#     Work/Life Balance
#     Management
#
# 3. parse "width: 80%" to 1 - 5 and NaN for 0%
#     b. add names to identify review-specific ratings
#
# #### TO DO:
#
# Load file
#
# 5. parse currently or not currently employed
#
# 6. analyze and remove duplicates
#
# 4. parse company-wide attributes
#     company_count_photos
#     company_count_reviews
#     company_count_salaries
#     company_empl
#     company_facebook
#     company_hq
#     company_indeed_url

# %%
import numpy as np
import pandas as pd
import re

# %%
file = "indeed_scrapy/scrape_data/company_reviews100to500fort20171020.csv"
df = pd.read_csv(file)

# %%
print(df.shape)
df.head()
# Out:
# (507557, 54)
#        agg_rating  bar_name1    bar_name2    bar_name3   bar_name4 bar_name5  \
# 0  width: 100.0%;  Stressful  Quick-paced  Competitive  Cut-throat  Balanced
# 1   width: 80.0%;  Stressful  Quick-paced  Competitive  Cut-throat  Balanced
# 2  width: 100.0%;  Stressful  Quick-paced  Competitive  Cut-throat  Balanced
# 3  width: 100.0%;  Stressful  Quick-paced  Competitive  Cut-throat  Balanced
# 4   width: 60.0%;  Stressful  Quick-paced  Competitive  Cut-throat  Balanced
#
#   bar_pct1 bar_pct2 bar_pct3 bar_pct4       ...        rating_scr3  \
# 0      58%      44%      36%      27%       ...                3.1
# 1      58%      44%      36%      27%       ...                3.1
# 2      58%      44%      36%      27%       ...                3.1
# 3      58%      44%      36%      27%       ...                3.1
# 4      58%      44%      36%      27%       ...                3.1
#
#   rating_scr4 rating_scr5     review_date  \
# 0         3.1         3.0  April 18, 2012
# 1         3.1         3.0  April 15, 2012
# 2         3.1         3.0  April 13, 2012
# 3         3.1         3.0   April 7, 2012
# 4         3.1         3.0   April 3, 2012
#
#                                         review_title  \
# 0       Many Opportunities in a Fast Growing Company
# 1                        good team mates,and friends
# 2              Challenging and educational workplace
# 3  Ideal professional career position and company...
# 4                                       Good company
#
#   reviewer_company_empl_status                     reviewer_job_location  \
# 0       (Current Employee) –                                  Victor, NY
# 1        (Former Employee) –    tri-state area,Nevada,California,Arizona
# 2       (Current Employee) –                              Saint Paul, MN
# 3        (Former Employee) –                                   Eagan, MN
# 4        (Former Employee) –                                 Orlando, FL
#
#                     reviewer_job_title                top_list  \
# 0    Plant Process Information Manager  Fortune 500 2017-03-31
# 1            senior service speicalest  Fortune 500 2017-03-31
# 2                  Route Sales Manager  Fortune 500 2017-03-31
# 3  Collections Specialist/ Call Center  Fortune 500 2017-03-31
# 4            Senior Service Specialist  Fortune 500 2017-03-31
#
#   work_life_rating
# 0   width: 100.0%;
# 1    width: 60.0%;
# 2     width: 0.0%;
# 3   width: 100.0%;
# 4    width: 20.0%;
#
# [5 rows x 54 columns]

# %% [markdown]
# 1. creating columns for uncertain company ratings and bars

# %%
company_bar_score_names = ["Quick-paced", 'Slow-paced', 'Stressful', 'Balanced', 'Competitive', 'Relaxed', 'Cut-throat']
bar_dict = {'bar_name1' : 'bar_pct1', 
            'bar_name2' : 'bar_pct2', 
            'bar_name3' : 'bar_pct3', 
            'bar_name4' : 'bar_pct4', 
            'bar_name5' : 'bar_pct5'
}

company_rate_names = ["Compensation/Benefits", "Culture", "Job Security/Advancement", "Work/Life Balance", "Management"]
rate_dict = {'rating_name1' : 'rating_scr1', 
            'rating_name2' : 'rating_scr2', 
            'rating_name3' : 'rating_scr3', 
            'rating_name4' : 'rating_scr4', 
            'rating_name5' : 'rating_scr5'
}

# %%
df['review_id'] = df.index + 127000
df['review_id'].head()
# Out:
# 0    127000
# 1    127001
# 2    127002
# 3    127003
# 4    127004
# Name: review_id, dtype: int64

# %% [markdown]
# Need to assign the appropriate rating columns and then match them to the new columns to be created in df

# %%
test = bar_dict.keys()
type(bar_dict)
# Out:
# dict

# %%
#testing for loop
test = df #need to add .copy() to test without changing df
i = 0
mask = test['bar_name2'] == company_bar_score_names[i]

test.loc[mask,company_bar_score_names[i]] = test.loc[mask,'bar_pct2']
print(company_bar_score_names[i])
test[company_bar_score_names[i]].head()
# Out:
# Quick-paced
# 0    44%
# 1    44%
# 2    44%
# 3    44%
# 4    44%
# Name: Quick-paced, dtype: object

# %%
df.filter(regex = '^b').head()
# Out:
#    bar_name1    bar_name2    bar_name3   bar_name4 bar_name5 bar_pct1  \
# 0  Stressful  Quick-paced  Competitive  Cut-throat  Balanced      58%
# 1  Stressful  Quick-paced  Competitive  Cut-throat  Balanced      58%
# 2  Stressful  Quick-paced  Competitive  Cut-throat  Balanced      58%
# 3  Stressful  Quick-paced  Competitive  Cut-throat  Balanced      58%
# 4  Stressful  Quick-paced  Competitive  Cut-throat  Balanced      58%
#
#   bar_pct2 bar_pct3 bar_pct4 bar_pct5
# 0      44%      36%      27%      20%
# 1      44%      36%      27%      20%
# 2      44%      36%      27%      20%
# 3      44%      36%      27%      20%
# 4      44%      36%      27%      20%

# %%
#bar names
for name in company_bar_score_names:
    for bar, bar_pct in bar_dict.items():
        mask = df[bar].str.strip() == name
        df.loc[mask, name] = df.loc[mask, bar_pct]

# %%
#rating names
for name in company_rate_names:
    for rat, rat_scr in rate_dict.items():
        mask = df[rat].str.strip() == name
        df.loc[mask, name] = df.loc[mask, rat_scr]

# %%
df.iloc[:, -13:].head()
# Out:
#    review_id Quick-paced Slow-paced Stressful Balanced Competitive Relaxed  \
# 0     127000         44%        NaN       58%      20%         36%     NaN
# 1     127001         44%        NaN       58%      20%         36%     NaN
# 2     127002         44%        NaN       58%      20%         36%     NaN
# 3     127003         44%        NaN       58%      20%         36%     NaN
# 4     127004         44%        NaN       58%      20%         36%     NaN
#
#   Cut-throat  Compensation/Benefits  Culture  Job Security/Advancement  \
# 0        27%                    3.5      3.2                       3.1
# 1        27%                    3.5      3.2                       3.1
# 2        27%                    3.5      3.2                       3.1
# 3        27%                    3.5      3.2                       3.1
# 4        27%                    3.5      3.2                       3.1
#
#    Work/Life Balance  Management
# 0                3.1         3.0
# 1                3.1         3.0
# 2                3.1         3.0
# 3                3.1         3.0
# 4                3.1         3.0

# %%
df.iloc[:,-12:].isnull().apply(pd.value_counts)
# Out:
#        Quick-paced  Slow-paced  Stressful  Balanced  Competitive  Relaxed  \
# False       504257         260     504257    503837       495017   304800
# True          3300      507297       3300      3720        12540   202757
#
#        Cut-throat  Compensation/Benefits   Culture  Job Security/Advancement  \
# False      208857               507557.0  507557.0                  507557.0
# True       298700                    NaN       NaN                       NaN
#
#        Work/Life Balance  Management
# False           507557.0    507557.0
# True                 NaN         NaN

# %% [markdown]
# Create functions for converting width to percent and string percent to float

# %%
def string_pct_to_float(strpct):
    try:
        return float(strpct.strip('%'))/100
    except:
        return strpct

def parse_widths_to_rating(string):
    
    try:
        result = string_pct_to_float(string.replace("width: ","").replace(";","").strip())
        if result == 0:
            return np.nan
        else:
            return result * 5
    except:
        return string

# %%
print(string_pct_to_float('80%'))
print(string_pct_to_float('100%'))
print(string_pct_to_float(123))
print(parse_widths_to_rating('width: 100.0%'))
print(parse_widths_to_rating(123))
print(parse_widths_to_rating('width: 100.0%'))
# Out:
# 0.8
# 1.0
# 123
# 5.0
# 123
# 5.0

# %%
#replace widths with 
widths_to_replace_mask = df.iloc[0,:].str.contains(r"^width: ") 

cols = df.columns[widths_to_replace_mask.fillna(False)]
cols
# Out:
# Index(['agg_rating', 'comp_ben_rating', 'culture_rating',
#        'jobsec_advancement_rating', 'management_rating', 'work_life_rating'],
#       dtype='object')

# %%
df[cols] = df[cols].applymap(parse_widths_to_rating)
# Out:
# agg_rating                   True
# comp_ben_rating              True
# culture_rating               True
# jobsec_advancement_rating    True
# management_rating            True
# work_life_rating             True
# Name: 0, dtype: object

# %%
df[cols].head()
# Out:
#    agg_rating  comp_ben_rating  culture_rating  jobsec_advancement_rating  \
# 0         5.0              5.0             5.0                        5.0
# 1         4.0              4.0             4.0                        4.0
# 2         5.0              NaN             NaN                        NaN
# 3         5.0              5.0             5.0                        5.0
# 4         3.0              3.0             4.0                        4.0
#
#    management_rating  work_life_rating
# 0                5.0               5.0
# 1                3.0               3.0
# 2                NaN               NaN
# 3                5.0               5.0
# 4                2.0               1.0

# %%
bar_names_count = df[list(bar_dict.keys())].apply(pd.Series.value_counts)
bar_names_count['totals'] = bar_names_count.sum(axis = 1)
bar_names_count = bar_names_count.append(pd.Series(bar_names_count.sum(axis=0), name = 'subtotals'))
bar_names_count
# Out:
#              bar_name1  bar_name2  bar_name3  bar_name4  bar_name5     totals
# Balanced       59880.0   102720.0   174419.0   147598.0    19220.0   503837.0
# Competitive    24660.0    57700.0   160838.0   211719.0    40100.0   495017.0
# Cut-throat         NaN     1280.0    11140.0    22420.0   174017.0   208857.0
# Quick-paced   332297.0   125920.0    27920.0    17960.0      160.0   504257.0
# Relaxed          800.0      880.0    19820.0    43280.0   240020.0   304800.0
# Slow-paced         NaN        NaN        NaN        NaN      260.0      260.0
# Stressful      86620.0   215757.0   110120.0    61280.0    30480.0   504257.0
# subtotals     504257.0   504257.0   504257.0   504257.0   504257.0  2521285.0

# %%
val_cols = bar_names_count.index[:7]
#from above: df.filter(regex="^rat").isnull().apply(pd.value_counts)
val_col_counts = df[val_cols].isnull().apply(pd.value_counts)
val_col_counts['totals'] = val_col_counts.sum(axis = 1)
val_col_counts = val_col_counts.append(pd.Series(val_col_counts.sum(axis=0), name = 'subtotals'))
val_col_counts
# Out:
#            Balanced  Competitive  Cut-throat  Quick-paced  Relaxed  \
# False        503837       495017      208857       504257   304800
# True           3720        12540      298700         3300   202757
# subtotals    507557       507557      507557       507557   507557
#
#            Slow-paced  Stressful   totals
# False             260     504257  2521285
# True           507297       3300  1031614
# subtotals      507557     507557  3552899

# %% [markdown]
# The values columns bnl check out with the others. I'll trust that the same goes for rating... it's late on Saturday and I don't have much time Sunday to work.

# %%
df.to_csv("indeed_scrapy/scrape_data/company_reviews100to500fort20171020" + "num_n_cowide sorted" + ".csv")
